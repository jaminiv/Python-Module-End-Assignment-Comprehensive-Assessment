# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Imported the csv file called fifa_data.csv
Employee=pd.read_csv('myexcel - myexcel.csv.csv')
Employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Preprocessing:
#Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)

height=Employee["Height"].value_counts()
print(height)
#Insight:Firstly when checking the values unde 'Height'column found dates there due to some error, so planned to use those dates and value as keys.
# Out:
# Height
# 06-Sep    59
# 06-Oct    47
# 06-Jul    45
# 06-Aug    43
# 06-Jun    42
# 06-Nov    40
# 06-Mar    33
# 06-May    32
# 06-Apr    29
# 7-0       27
# 06-Jan    16
# 06-Feb    16
# 6-0       10
# 07-Jan     7
# 07-Mar     5
# 05-Nov     3
# 07-Feb     3
# 05-Sep     1
# Name: count, dtype: int64

# %%
#Insight: I had created to dictionary to make it easier to add the correct values to the column and i implemented to the table as it is and go them updated.
Employee['Height'].replace({"06-Sep":150,
                            "06-Oct":155,
                            "06-Jul":160,
                            "06-Aug":170,
                            "06-Jun":177,
                            "06-Nov":151,
                            "06-Mar":153,    
                            "06-May":162,    
                            "06-Apr":171,   
                            "7-0":180,       
                            "06-Jan":165,    
                            "06-Feb":175,    
                            "6-0":178,     
                            "07-Jan":154,     
                            "07-Mar":156,     
                            "05-Nov":164,     
                            "07-Feb":167,     
                            "05-Sep":159  
                           },inplace=True)
Employee
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11276\3207938137.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Employee['Height'].replace({"06-Sep":150,
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     162     205
# ...

# %%
#Analysis Tasks:
#1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)

team=Employee["Team"].value_counts()
total_employees = len(Employee)
percentage_split = (team / total_employees) * 100
print(percentage_split)

plt.figure(figsize=(10, 6))
team.plot(kind='bar', color='indigo')
plt.xlabel('Team')
plt.ylabel('Percentage split')
plt.title('Percentage')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
#Insight: Here we find out there 30 teams and their percentiles are as given below:
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
#2. Segregate employees based on their positions within the company. (2 marks)

pt=Employee.sort_values(by=["Position"], ascending=True)
print(pt)
position_counts = Employee['Position'].value_counts()
plt.pie(position_counts,labels=position_counts.index,autopct="%1.1f%%")
plt.title("Employee Distribution by Position")
plt.show()
#Insight: By segregating the employee on basis of 'Position', we come to a conclusion that there are more employees from the Position SG.
# Out:
#                 Name               Team  Number Position  Age  Height  Weight  \
# 457         Priyanka          Utah Jazz      34        C   25     156     231
# 135    Alan Williams       Phoenix Suns      15        C   23     170     260
# 321   Tiago Splitter      Atlanta Hawks      11        C   31     151     245
# 322   Walter Tavares      Atlanta Hawks      22        C   24     156     260
# 128         Alex Len       Phoenix Suns      21        C   22     154     260
# ..               ...                ...     ...      ...  ...     ...     ...
# 325     Troy Daniels  Charlotte Hornets      30       SG   24     171     205
# 324    Nicolas Batum  Charlotte Hornets       5       SG   27     170     200
# 249     James Harden    Houston Rockets      13       SG   26     162     220
# 317  Lamar Patterson      Atlanta Hawks      13       SG   24     162     225
# 219  Khris Middleton    Milwaukee Bucks      22       SG   24     170     234
#
# ...

# %%
#3. Identify the predominant age group among employees. (2 marks)

age=Employee['Age'].value_counts()
index_age = Employee['Age'].value_counts().idxmax() #index max
max_age = Employee['Age'].value_counts().max() #max number of times

print("\nThe predominant age group amoung employees is",index_age,".Total number of people with the same age group is ",max_age)
plt.bar(age.index, age.values,color="maroon")
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Age Group')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
#Insight: Most of the employees hired, are hired at the age of 24 years.
# Out:
# The predominant age group amoung employees is 24 .Total number of people with the same age group is  47

# %%
#4. Discover which team and position have the highest salary expenditure. (2 marks)

saltab = pd.DataFrame(Employee)
grouped_data = saltab.groupby(['Team','Position'])
total_salary_by_group = grouped_data['Salary'].sum()
highest_expenditure_group = total_salary_by_group.idxmax()
highest_spending_team = highest_expenditure_group[0]
highest_spending_position = highest_expenditure_group[1]
print(f"Team with Highest Salary Expenditure: {highest_spending_team}")
print(f"Position with Highest Salary Expenditure: {highest_spending_position}")
total_salary_by_group.plot(kind='line',color='maroon')
plt.xlabel('Team,Position')
plt.ylabel('Total Salary')
plt.title('Salary Expenditure')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
#Insight: In this we can conclude that Los Angles Lakers team is getting higher paid than other teams and the position getting higher paid is SF.
# Out:
# Team with Highest Salary Expenditure: Los Angeles Lakers
# Position with Highest Salary Expenditure: SF

# %%
#5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)

saltab = pd.DataFrame(Employee)
if len(df) < 2:
  print("Insufficient data for correlation analysis. Minimum of 2 data points required.")
else:
  correlation = df['Age'].corr(df['Salary'])
  print(f"Correlation between Age and Salary: {correlation:.2f}")

sns.lineplot(x='Age', y='Salary', data=df,color='maroon')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between Age and Salary')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
#Insight: In conclusion, there is no such correlation between age adn salary.
# Out:
# Correlation between Age and Salary: 0.21
